# %% [markdown]
# # Final Result Notebook
#
# Steps :
# 1. Search Full questions+title in *arq_ans_ques* index
# 2. Save these results as Baseline-run
#
# ----
# 1. Now again - Search Full questions+title in *arq_ans_ques* index
# 2. Rerank them using BERT - save results
# 3. Merge Baseline-run and Rerank-run

# %%
import glob
from tqdm.notebook import tqdm
import os
import jsonlines
import re
import xml.etree.ElementTree as ET
from elasticsearch import Elasticsearch
import re
from collections import defaultdict
import numpy as np
from scipy import spatial
import numpy as np
import gc
import math
import torch
from transformers import *

ques_path = '/data/szr207/dataset/ArqMath/jsons/questions/all.ques.jsonl'
ans_path = '/data/szr207/dataset/ArqMath/jsons/answers/all.ans.jsonl'
topic_file_path = "/data/szr207/dataset/ArqMath/Task1/Topics/Topics_V2.0.xml"

# %%
class Topic:
    """
    This class shows a topic for task 1. Each topic has an topic_id which is str, a title and question which
    is the question body and a list of tags.
    """

    def __init__(self, topic_id, title, question, tags):
        self.topic_id = topic_id
        self.title = title
        self.question = question
        self.lst_tags = tags


class TopicReader:
    """
    This class takes in the topic file path and read all the topics into a map. The key in this map is the topic id
    and the values are Topic which has 4 attributes: id, title, question and list of tags for each topic.

    To see each topic, use the get_topic method, which takes the topic id and return the topic in Topic object and
    you have access to the 4 attributes mentioned above.
    """

    def __init__(self, topic_file_path):
        self.__map_topics = self.__read_topics(topic_file_path)

    def __read_topics(self, topic_file_path):
        map_topics = {}
        tree = ET.parse(topic_file_path)
        root = tree.getroot()
        for child in root:
            topic_id = child.attrib['number']
            title = child[0].text
            question = child[1].text
            lst_tag = child[2].text.split(",")
            map_topics[topic_id] = Topic(topic_id, title, question, lst_tag)
        return map_topics

    def get_topic(self, topic_id):
        if topic_id in self.__map_topics:
            return self.__map_topics[topic_id]
        return None

def remove_stop(query):
    with open('englishST.txt') as f:
        all_stopwords = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    all_stopwords = [x.strip() for x in all_stopwords] 
    text_tokens = query.split(' ')
    query = [word for word in text_tokens if not word in all_stopwords]
    query = ' '.join(query)
    return query

def remove_punct(my_str):
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    # To take input from the user
    # my_str = input("Enter a string: ")

    # remove punctuation from the string
    no_punct = ""
    for char in my_str:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct

es = Elasticsearch(['http://csxindex05:9200/'], verify_certs=True)
queries = []
#"In this example, the title and the question body of topic with id A.1 is printed."
topic_reader = TopicReader(topic_file_path)
dict_q_a = defaultdict(list)


topic_list = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        topic_list.append(line.split('\t')[0])

topic_list = list(set(topic_list))

list_p = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        list_p.append(line.split('\t')[2])

list_p = list(set(list_p))

# with open('psu-task1-mlt.base-auto-both-A.tsv', 'w') as eval_file:
for topic_id in tqdm(topic_list):
    title = re.sub('<[^<]+?>', '', topic_reader.get_topic(topic_id).title)
    body = topic_reader.get_topic(topic_id).question
    body_pro = re.sub('<[^<]+?>', '', body)
    query = title + '. ' + body_pro
    queries.append(query)
    query = query.lower()
    query = remove_stop(query)
#         print(topic_id, query)
    body = {
        "size": 1000,
         "query": {
               "more_like_this" : {
            "fields" : ["body"],
            "like" : query,
            }
        }
    }

    res = es.search(index="arq_ans_ques", body=body)

    for result in res['hits']['hits']:
        if str(result['_source']['post_id']) in list_p:
            dict_q_a[topic_id].append(result['_source']['post_id'])

#         count = 1
#         for result in res['hits']['hits']:
#             if str(result['_source']['post_id']) in list_p:
#                 eval_file.write(topic_id+'\t' +str(result['_source']['post_id'])+'\t'+str(count)+'\t'+ str(result['_score'])+'\t'+ 'mlt_base'+'\n')
#                 count+=1

# %%
dict_ques = {}
dict_ans = {}
dict_aid_body = {}

with jsonlines.open(os.path.join(ques_path)) as reader:
        for obj in tqdm(reader):
            dict_ques[obj['post_id']] = obj
    
with jsonlines.open(os.path.join(ans_path)) as reader:
        for obj in tqdm(reader):
            dict_ans[obj['post_id']] = obj

for a_id in tqdm(list(dict_ans.keys())):
    ans_body = re.sub('<[^<]+?>', '',  dict_ans[a_id]['body'])
    qid = dict_ans[a_id]['parent_id']
    ques_body = re.sub('<[^<]+?>', '',  dict_ques[qid]['body'])
    ques_title = re.sub('<[^<]+?>', '',  dict_ques[qid]['title'])
    dict_aid_body[a_id] = ques_title + '. ' + ques_body #+ '. ' + ans_body

# %% [markdown]
# ### ReRanking using fine-tuned HF RoBERTa-Base

# %%
from transformers import pipeline
from transformers import *

feat_ext = pipeline("feature-extraction", model="/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-4000000", tokenizer='roberta-base', device=0) #our finetuned model
# feat_ext = pipeline("feature-extraction", model="roberta-base", tokenizer='roberta-base', device=0) #our finetuned model
ques_emb = []
for query in tqdm(queries):
    ques_emb.append(np.mean(feat_ext(query)[0], axis=0))
    
del feat_ext
torch.cuda.empty_cache()
gc.collect()
# Out:
# Model name '/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-4000000' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, bart-large, bart-large-mnli, bart-large-cnn, bart-large-xsum, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2
# ...

# %%
dict_q_idx = {}
count = 0
for topic_id in tqdm(topic_list):
    dict_q_idx[topic_id]=0
    count+=1

# %%
def Sort_Tuple(tup):  
    # reverse = None (Sorts in Ascending order)  
    # key is set to sort using second element of  
    # sublist lambda has been used  
    tup.sort(key = lambda x: x[2])
    return tup

# %%
def reduce_str(body):
    tokenizer =  RobertaTokenizer.from_pretrained('roberta-base')
    encoded = tokenizer.encode(body)[:510]
    return tokenizer.decode(encoded)

# %%
result_list = []
count = 0
for qid in tqdm(topic_reader._TopicReader__map_topics):
    tup_postid_sim = []
    feat_ext = pipeline("feature-extraction", model="/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-3000000", tokenizer='roberta-base', device=0) #our finetuned model
    for post_id in tqdm(dict_q_a[qid]):
        try:
            feat = feat_ext(dict_aid_body[int(post_id)])[0]
            ans_emb = np.mean(feat, axis=0)
            del feat
            gc.collect()
        except:
            print(post_id)
            continue
        result = 1 - spatial.distance.cosine(ques_emb[dict_q_idx[qid]], ans_emb)
        
        if math.isnan(result):
            count+=1
            print(qid, post_id, count)
            continue
        tup_postid_sim.append((qid,post_id,result))
    try:
        del feat_ext
        gc.collect()
        torch.cuda.empty_cache()
    except:
        print(qid)
        continue
        
    result_list.append(Sort_Tuple(tup_postid_sim)[::-1][:1000])
# Out:
# ...
# Model name '/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-3000000' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, bart-large, bart-large-mnli, bart-large-cnn, bart-large-xsum, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2
# ...

# %%
with open('psu-task1-mlt.bert-auto-both-A.tsv', 'w') as eval_file:
    for res in result_list:
        count = 1
        for tuples in res:
            eval_file.write(tuples[0]+'\t' + str(tuples[1]) +'\t'+str(count)+'\t'+ str(tuples[2])+'\t'+ 'mlt_bert'+'\n')
            count+=1

# %%
result_list = []
count = 0
for qid in tqdm(list(topic_list)):
    tup_postid_sim = []
    feat_ext = pipeline("feature-extraction", model="/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-4000000", tokenizer='roberta-base', device=0) #our finetuned model
#     feat_ext = pipeline("feature-extraction", model="roberta-base", tokenizer='roberta-base', device=0) #our finetuned model

    for post_id in tqdm(dict_q_a[qid]):
        try:
            feat = feat_ext(reduce_str(dict_aid_body[post_id]))[0]
            ans_emb = np.mean(feat, axis=0)
        except:
            print('CUDA error: an illegal memory access was encountered', post_id)
            break
        result = 1 - spatial.distance.cosine(ques_emb[dict_q_idx[qid]], ans_emb)
        
        if math.isnan(result):
            count+=1
            print(qid, post_id, count)
            break
        tup_postid_sim.append((qid,post_id,result))
    try:
        del feat_ext
        gc.collect()
        torch.cuda.empty_cache()
    except:
        print(qid)
        break
    result_list.append(Sort_Tuple(tup_postid_sim)[::-1][:1000])
# Out:
# ...
# Model name '/data/szr207/github/transformers/examples/language-modeling/output/checkpoint-4000000' was not found in model name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-japanese, bert-base-japanese-whole-word-masking, bert-base-japanese-char, bert-base-japanese-char-whole-word-masking, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased, bart-large, bart-large-mnli, bart-large-cnn, bart-large-xsum, openai-gpt, transfo-xl-wt103, gpt2, gpt2-medium, gpt2-large, gpt2-xl, distilgpt2, ctrl, xlnet-base-cased, xlnet-large-cased, xlm-mlm-en-2
# ...

# %%
# del feat_ext
gc.collect()
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-4bc40c3abeea> in <module>
#       1 # del feat_ext
#       2 gc.collect()
# ----> 3 torch.cuda.empty_cache()
#
# /data/szr207/conda/envs/faiss/lib/python3.7/site-packages/torch/cuda/memory.py in empty_cache()
#      84     """
#      85     if is_initialized():
# ---> 86         torch._C._cuda_emptyCache()
#      87
#      88
#
# RuntimeError: CUDA error: an illegal memory access was encountered

# %%
with open('tf.psu-task1-prim.final.bert-auto-both-A.tsv', 'w') as eval_file:
    for res in result_list:
        count = 1
        for tuples in res:
            eval_file.write(tuples[0]+'\t'+ '1\t' + str(tuples[1]) +'\t'+str(count)+'\t'+ str(tuples[2])+'\t'+ 'bert_cls'+'\n')
#             eval_file.write(tuples[0]+'\t' + str(tuples[1]) +'\t'+str(count)+'\t'+ str(tuples[2])+'\t'+ 'mlt_bert'+'\n')
            count+=1

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.roberta-base-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2398

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.bert-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2103

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.final.bert-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2088

# %%
from trectools import TrecRun, TrecEval, fusion

runs_path = '/data/szr207/projects/ArqMath/runs'
r1 = TrecRun(os.path.join("tf.psu-task1-prim.mlt-auto-both-A.tsv"))
r2 = TrecRun(os.path.join("tf.psu-task1-prim.anserini-auto-both-A.tsv"))
r3 = TrecRun(os.path.join("tf.psu-task1-prim.roberta-base-auto-both-A.tsv"))
# Easy way to create new baselines by fusing existing runs:
fused_run = fusion.reciprocal_rank_fusion([r1,r2,r3])

# Save run to disk with all its topics
fused_run.print_subset("tf.psu-task1-rrf2.prim.mlt.roberta-auto-both-A.tsv", topics=fused_run.topics())
# Out:
# File tf.psu-task1-rrf2.prim.mlt.roberta-auto-both-A.tsv writen.

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg ../runs/qrel_task1 tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv
# Out:
# ndcg                  	all	0.3142

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	16320
# num_rel               	all	1804
# num_rel_ret           	all	902
# map                   	all	0.0970
# gm_map                	all	0.0168
# Rprec                 	all	0.1188
# bpref                 	all	0.0938
# recip_rank            	all	0.3211
# iprec_at_recall_0.00  	all	0.3549
# iprec_at_recall_0.10  	all	0.2130
# iprec_at_recall_0.20  	all	0.1467
# iprec_at_recall_0.30  	all	0.1221
# iprec_at_recall_0.40  	all	0.1010
# iprec_at_recall_0.50  	all	0.0876
# iprec_at_recall_0.60  	all	0.0728
# iprec_at_recall_0.70  	all	0.0551
# iprec_at_recall_0.80  	all	0.0346
# iprec_at_recall_0.90  	all	0.0162
# iprec_at_recall_1.00  	all	0.0114
# P_5                   	all	0.1662
# P_10                  	all	0.1494
# P_15                  	all	0.1377
# P_20                  	all	0.1325
# P_30                  	all	0.1195
# P_100                 	all	0.0777
# ...

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 ../runs/qrel_task1 ../final_runs/prim_psu-task1-auto-both-A.tsv
# Out:
# runid                 	all	mlt_base
# num_q                 	all	77
# num_ret               	all	7789
# num_rel               	all	1804
# num_rel_ret           	all	761
# map                   	all	0.0822
# gm_map                	all	0.0105
# Rprec                 	all	0.0985
# bpref                 	all	0.0716
# recip_rank            	all	0.2188
# iprec_at_recall_0.00  	all	0.2653
# iprec_at_recall_0.10  	all	0.1847
# iprec_at_recall_0.20  	all	0.1423
# iprec_at_recall_0.30  	all	0.1186
# iprec_at_recall_0.40  	all	0.1013
# iprec_at_recall_0.50  	all	0.0860
# iprec_at_recall_0.60  	all	0.0759
# iprec_at_recall_0.70  	all	0.0461
# iprec_at_recall_0.80  	all	0.0235
# iprec_at_recall_0.90  	all	0.0126
# iprec_at_recall_1.00  	all	0.0078
# P_5                   	all	0.1299
# P_10                  	all	0.1156
# P_15                  	all	0.1108
# P_20                  	all	0.1130
# P_30                  	all	0.1009
# P_100                 	all	0.0834
# P_200                 	all	0.0494
# ...

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.anserini.bert-auto-both-A.tsv
# Out:
# ndcg                  	all	0.1956

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.anserini-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2460

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg ../runs/qrel_task1 tf.psu-task1-rrf.prim.mlt.roberta-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2798

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.mlt-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2712

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	16320
# num_rel               	all	1804
# num_rel_ret           	all	902
# map                   	all	0.0970
# gm_map                	all	0.0168
# Rprec                 	all	0.1188
# bpref                 	all	0.0938
# recip_rank            	all	0.3211
# iprec_at_recall_0.00  	all	0.3549
# iprec_at_recall_0.10  	all	0.2130
# iprec_at_recall_0.20  	all	0.1467
# iprec_at_recall_0.30  	all	0.1221
# iprec_at_recall_0.40  	all	0.1010
# iprec_at_recall_0.50  	all	0.0876
# iprec_at_recall_0.60  	all	0.0728
# iprec_at_recall_0.70  	all	0.0551
# iprec_at_recall_0.80  	all	0.0346
# iprec_at_recall_0.90  	all	0.0162
# iprec_at_recall_1.00  	all	0.0114
# P_5                   	all	0.1662
# P_10                  	all	0.1494
# P_15                  	all	0.1377
# P_20                  	all	0.1325
# P_30                  	all	0.1195
# P_100                 	all	0.0777
# ...

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 ./final_runs/Linked_MSE.tsv
# Out:
# runid                 	all	MSE
# num_q                 	all	71
# num_ret               	all	768
# num_rel               	all	1770
# num_rel_ret           	all	395
# map                   	all	0.2091
# gm_map                	all	0.0749
# Rprec                 	all	0.2516
# bpref                 	all	0.2325
# recip_rank            	all	0.7471
# iprec_at_recall_0.00  	all	0.7727
# iprec_at_recall_0.10  	all	0.6429
# iprec_at_recall_0.20  	all	0.4064
# iprec_at_recall_0.30  	all	0.2602
# iprec_at_recall_0.40  	all	0.1838
# iprec_at_recall_0.50  	all	0.1301
# iprec_at_recall_0.60  	all	0.0669
# iprec_at_recall_0.70  	all	0.0658
# iprec_at_recall_0.80  	all	0.0196
# iprec_at_recall_0.90  	all	0.0115
# iprec_at_recall_1.00  	all	0.0000
# P_5                   	all	0.5437
# P_10                  	all	0.4169
# P_15                  	all	0.3221
# P_20                  	all	0.2655
# P_30                  	all	0.1854
# P_100                 	all	0.0556
# P_200                 	all	0.0278
# ...

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 final_runs/DPRL_task1_auto_both_A3.tsv > ./trec_results/DPRL_task1_auto_both_A3.txt

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 final_runs/prim_zbMATH-task1-auto-both-P.tsv > ./trec_results/prim_zbMATH-task1-auto-both-P.txt

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 final_runs/prim_MIRMU-task1-Ensemble-auto-both-A.tsv > ./trec_results/prim_MIRMU-task1-Ensemble-auto-both-A.txt

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 final_runs/prim_MathDowsers-task1-alpha05noReRank-auto-both-A.tsv > ./trec_results/prim_MathDowsers-task1-alpha05noReRank-auto-both-A.txt

# %%
# !java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 final_runs/tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv > ./trec_results/tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.txt

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1  tf.psu-task1-rrf.prim.mlt.anserini-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	13531
# num_rel               	all	1804
# num_rel_ret           	all	875
# map                   	all	0.0978
# gm_map                	all	0.0151
# Rprec                 	all	0.1205
# bpref                 	all	0.0888
# recip_rank            	all	0.2786
# iprec_at_recall_0.00  	all	0.3192
# iprec_at_recall_0.10  	all	0.2184
# iprec_at_recall_0.20  	all	0.1558
# iprec_at_recall_0.30  	all	0.1324
# iprec_at_recall_0.40  	all	0.1066
# iprec_at_recall_0.50  	all	0.0886
# iprec_at_recall_0.60  	all	0.0779
# iprec_at_recall_0.70  	all	0.0617
# iprec_at_recall_0.80  	all	0.0316
# iprec_at_recall_0.90  	all	0.0136
# iprec_at_recall_1.00  	all	0.0100
# P_5                   	all	0.1558
# P_10                  	all	0.1506
# P_15                  	all	0.1359
# P_20                  	all	0.1325
# P_30                  	all	0.1169
# P_100                 	all	0.0814
# ...

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1  tf.psu-task1-rrf.prim.mlt.roberta-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	12432
# num_rel               	all	1804
# num_rel_ret           	all	823
# map                   	all	0.0814
# gm_map                	all	0.0120
# Rprec                 	all	0.1042
# bpref                 	all	0.0854
# recip_rank            	all	0.2808
# iprec_at_recall_0.00  	all	0.3036
# iprec_at_recall_0.10  	all	0.1845
# iprec_at_recall_0.20  	all	0.1323
# iprec_at_recall_0.30  	all	0.1031
# iprec_at_recall_0.40  	all	0.0926
# iprec_at_recall_0.50  	all	0.0753
# iprec_at_recall_0.60  	all	0.0647
# iprec_at_recall_0.70  	all	0.0401
# iprec_at_recall_0.80  	all	0.0238
# iprec_at_recall_0.90  	all	0.0118
# iprec_at_recall_1.00  	all	0.0050
# P_5                   	all	0.1351
# P_10                  	all	0.1299
# P_15                  	all	0.1177
# P_20                  	all	0.1130
# P_30                  	all	0.1052
# P_100                 	all	0.0762
# ...

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1  tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	16320
# num_rel               	all	1804
# num_rel_ret           	all	902
# map                   	all	0.0970
# gm_map                	all	0.0168
# Rprec                 	all	0.1188
# bpref                 	all	0.0938
# recip_rank            	all	0.3211
# iprec_at_recall_0.00  	all	0.3549
# iprec_at_recall_0.10  	all	0.2130
# iprec_at_recall_0.20  	all	0.1467
# iprec_at_recall_0.30  	all	0.1221
# iprec_at_recall_0.40  	all	0.1010
# iprec_at_recall_0.50  	all	0.0876
# iprec_at_recall_0.60  	all	0.0728
# iprec_at_recall_0.70  	all	0.0551
# iprec_at_recall_0.80  	all	0.0346
# iprec_at_recall_0.90  	all	0.0162
# iprec_at_recall_1.00  	all	0.0114
# P_5                   	all	0.1662
# P_10                  	all	0.1494
# P_15                  	all	0.1377
# P_20                  	all	0.1325
# P_30                  	all	0.1195
# P_100                 	all	0.0777
# ...

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 tf.psu-task1-prim.anserini-auto-both-A.tsv
# Out:
# runid                 	all	anserini
# num_q                 	all	77
# num_ret               	all	10502
# num_rel               	all	1804
# num_rel_ret           	all	660
# map                   	all	0.0784
# gm_map                	all	0.0087
# Rprec                 	all	0.1118
# bpref                 	all	0.0926
# recip_rank            	all	0.2858
# iprec_at_recall_0.00  	all	0.3123
# iprec_at_recall_0.10  	all	0.1972
# iprec_at_recall_0.20  	all	0.1389
# iprec_at_recall_0.30  	all	0.1105
# iprec_at_recall_0.40  	all	0.0844
# iprec_at_recall_0.50  	all	0.0638
# iprec_at_recall_0.60  	all	0.0449
# iprec_at_recall_0.70  	all	0.0245
# iprec_at_recall_0.80  	all	0.0087
# iprec_at_recall_0.90  	all	0.0072
# iprec_at_recall_1.00  	all	0.0058
# P_5                   	all	0.1610
# P_10                  	all	0.1390
# P_15                  	all	0.1247
# P_20                  	all	0.1143
# P_30                  	all	0.1082
# P_100                 	all	0.0695
# P_200                 	all	0.0429
# ...

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  ../runs/qrel_task1 ../final_runs/prim_psu-task1-auto-both-P.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	7789
# num_rel               	all	1804
# num_rel_ret           	all	761
# map                   	all	0.0536
# gm_map                	all	0.0076
# Rprec                 	all	0.0696
# bpref                 	all	0.0413
# recip_rank            	all	0.0991
# iprec_at_recall_0.00  	all	0.1369
# iprec_at_recall_0.10  	all	0.1057
# iprec_at_recall_0.20  	all	0.0954
# iprec_at_recall_0.30  	all	0.0849
# iprec_at_recall_0.40  	all	0.0757
# iprec_at_recall_0.50  	all	0.0689
# iprec_at_recall_0.60  	all	0.0627
# iprec_at_recall_0.70  	all	0.0379
# iprec_at_recall_0.80  	all	0.0182
# iprec_at_recall_0.90  	all	0.0093
# iprec_at_recall_1.00  	all	0.0040
# P_5                   	all	0.0338
# P_10                  	all	0.0545
# P_15                  	all	0.0589
# P_20                  	all	0.0623
# P_30                  	all	0.0645
# P_100                 	all	0.0790
# ...

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg  ../runs/qrel_task1 tf.psu-task1-prim.mlt-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2712

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg  ../runs/qrel_task1 ../final_runs/prim_psu-task1-auto-both-A2.tsv
# Out:
# ndcg                  	all	0.2105

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m ndcg  ../runs/qrel_task1 ./final_runs/prim_MIRMU-task1-Ensemble-auto-both-A.tsv
# Out:
# ndcg                  	all	0.2378

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2   ../runs/qrel_task1 tf.psu-task1-rrf2.prim.mlt.roberta-auto-both-A.tsv
# Out:
# runid                 	all	reciprocal_rank_fusion_k=60
# num_q                 	all	77
# num_ret               	all	16320
# num_rel               	all	1804
# num_rel_ret           	all	902
# map                   	all	0.0970
# gm_map                	all	0.0168
# Rprec                 	all	0.1188
# bpref                 	all	0.0938
# recip_rank            	all	0.3211
# iprec_at_recall_0.00  	all	0.3549
# iprec_at_recall_0.10  	all	0.2130
# iprec_at_recall_0.20  	all	0.1467
# iprec_at_recall_0.30  	all	0.1221
# iprec_at_recall_0.40  	all	0.1010
# iprec_at_recall_0.50  	all	0.0876
# iprec_at_recall_0.60  	all	0.0728
# iprec_at_recall_0.70  	all	0.0551
# iprec_at_recall_0.80  	all	0.0346
# iprec_at_recall_0.90  	all	0.0162
# iprec_at_recall_1.00  	all	0.0114
# P_5                   	all	0.1662
# P_10                  	all	0.1494
# P_15                  	all	0.1377
# P_20                  	all	0.1325
# P_30                  	all	0.1195
# P_100                 	all	0.0777
# ...

# %%
r1 = TrecRun(os.path.join("tf.psu-task1-prim.mlt-auto-both-A.tsv"))
r2 = TrecRun(os.path.join("tf.psu-task1-prim.anserini-auto-both-A.tsv"))
r3 = TrecRun(os.path.join("tf.psu-task1-prim.roberta-base-auto-both-A.tsv"))

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m num_rel_ret  ../runs/qrel_task1 tf.psu-task1-prim.mlt-auto-both-A.tsv
# Out:
# num_rel_ret           	all	781

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m num_rel_ret  ../runs/qrel_task1 tf.psu-task1-prim.anserini-auto-both-A.tsv
# Out:
# num_rel_ret           	all	660

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m num_rel_ret  ../runs/qrel_task1 tf.psu-task1-prim.roberta-base-auto-both-A.tsv
# Out:
# num_rel_ret           	all	761

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  -m ndcg ../runs/qrel_task1 tf.psu-task1-prim.anserini.bert-auto-both-A.tsv
# Out:
# ndcg                  	all	0.1956

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2  -m recall ../runs/qrel_task1 ./final_runs/tf.psu-task1-rrf.prim.mlt.anserini.roberta-auto-both-A.tsv
# Out:
# recall_5              	all	0.0417
# recall_10             	all	0.0816
# recall_15             	all	0.1165
# recall_20             	all	0.1444
# recall_30             	all	0.1809
# recall_100            	all	0.3221
# recall_200            	all	0.4539
# recall_500            	all	0.4726
# recall_1000           	all	0.4726

# %%
! java -jar jtreceval-0.0.5-jar-with-dependencies.jar -l2 -m recall ../runs/qrel_task1 ./final_runs/prim_MathDowsers-task1-alpha05noReRank-auto-both-A.tsv
# Out:
# recall_5              	all	0.0561
# recall_10             	all	0.0942
# recall_15             	all	0.1207
# recall_20             	all	0.1593
# recall_30             	all	0.2165
# recall_100            	all	0.4397
# recall_200            	all	0.4852
# recall_500            	all	0.4852
# recall_1000           	all	0.4852

# %%
filepath = 'BM25+tf+tf.BERT.ndcg.txt'
bert_ndcg = []
topic_idx = []
mathdowsers = []

dict_bert = {}
dict_math = {}
with open(filepath) as fp:
    for cnt, line in enumerate(fp):
#         bert_ndcg.append(line.split('\t')[2].rstrip())
#         topc_idx.append(line.split('\t')[1].rstrip())
        topic_idx.append(line.split('\t')[1].rstrip()[2:])
        bert_ndcg.append(float(line.split('\t')[2].rstrip()))
        dict_bert[line.split('\t')[1].rstrip()] = float(line.split('\t')[2].rstrip())

# %%
filepath = "MathDowsers.ndcg.txt"

with open(filepath) as fp:
    for cnt, line in enumerate(fp):
        mathdowsers.append(float(line.split('\t')[2].rstrip()))
        dict_math[line.split('\t')[1].rstrip()] = float(line.split('\t')[2].rstrip())

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [30, 10]

plt.plot(bert_ndcg, label='BM25+tf+tf.BERT')
plt.plot(mathdowsers, label = 'MathDowsers')
plt.ylabel('NDCG')
plt.legend(loc='lower right')

locs, labels = plt.xticks()
plt.xticks(np.arange(0, 1, step=0.129))
plt.xticks(np.arange(77), topic_idx) 
plt.grid(True)

# plt.xticks(X, topic_idx)
plt.show()

# %% [markdown]
# 21, 23, 29, 32, 38, 40, 5, 93, 98 - IDS where our system is just too good for MathDowsers

# %%
count_bert = 0
better_bert = []
better_math = []
for idx in dict_math:
    if dict_math[idx] < dict_bert[idx]:
        count_bert+=1
        better_bert.append(idx)
    else:
        better_math.append(idx)

# %%
count_bert = 0
better_bert = []
better_math = []
for idx in dict_math:
    if dict_math[idx] < dict_bert[idx]:
        count_bert+=1
        print(idx,'bert')
    else:
        print(idx,'mathdowserx')
# Out:
# A.1 bert
# A.10 bert
# A.11 bert
# A.12 mathdowserx
# A.13 mathdowserx
# A.14 mathdowserx
# A.15 mathdowserx
# A.16 mathdowserx
# A.17 bert
# A.18 bert
# A.19 mathdowserx
# A.20 mathdowserx
# A.21 bert
# A.23 bert
# A.24 bert
# A.26 mathdowserx
# A.27 mathdowserx
# A.28 bert
# A.29 bert
# A.3 mathdowserx
# A.30 mathdowserx
# A.32 bert
# A.33 bert
# A.35 bert
# A.36 bert
# A.37 bert
# A.38 bert
# A.39 mathdowserx
# A.4 mathdowserx
# A.40 bert
# A.41 bert
# A.42 bert
# A.43 mathdowserx
# A.44 bert
# A.45 mathdowserx
# A.47 bert
# A.48 mathdowserx
# A.49 bert
# A.5 bert
# A.50 mathdowserx
# A.51 mathdowserx
# A.52 mathdowserx
# A.53 mathdowserx
# A.54 bert
# A.55 mathdowserx
# A.56 mathdowserx
# A.58 mathdowserx
# A.59 mathdowserx
# A.60 mathdowserx
# A.61 bert
# A.62 mathdowserx
# A.63 mathdowserx
# A.65 mathdowserx
# A.66 bert
# A.67 bert
# A.68 bert
# A.69 mathdowserx
# A.7 bert
# A.72 mathdowserx
# A.74 bert
# A.75 mathdowserx
# A.77 mathdowserx
# A.79 mathdowserx
# A.8 mathdowserx
# ...

# %%
count_bert # number of queries our system is better than MathDowsers
# Out:
# 36

# %%
77-count_bert # Number of Queries Mathdowsers is better
# Out:
# 41

# %%
import scipy

# %%
correlation, p_value = scipy.stats.pearsonr(mathdowsers, bert_ndcg) #  we can see there is negative correlation between our runs - which means we are doing something very different from what MathDowsers are doing
print(correlation)
# Out:
# -0.09260507106046305

# %%
class Topic:
    """
    This class shows a topic for task 1. Each topic has an topic_id which is str, a title and question which
    is the question body and a list of tags.
    """

    def __init__(self, topic_id, title, question, tags):
        self.topic_id = topic_id
        self.title = title
        self.question = question
        self.lst_tags = tags


class TopicReader:
    """
    This class takes in the topic file path and read all the topics into a map. The key in this map is the topic id
    and the values are Topic which has 4 attributes: id, title, question and list of tags for each topic.

    To see each topic, use the get_topic method, which takes the topic id and return the topic in Topic object and
    you have access to the 4 attributes mentioned above.
    """

    def __init__(self, topic_file_path):
        self.__map_topics = self.__read_topics(topic_file_path)

    def __read_topics(self, topic_file_path):
        map_topics = {}
        tree = ET.parse(topic_file_path)
        root = tree.getroot()
        for child in root:
            topic_id = child.attrib['number']
            title = child[0].text
            question = child[1].text
            lst_tag = child[2].text.split(",")
            map_topics[topic_id] = Topic(topic_id, title, question, lst_tag)
        return map_topics

    def get_topic(self, topic_id):
        if topic_id in self.__map_topics:
            return self.__map_topics[topic_id]
        return None


es = Elasticsearch(['http://csxindex05:9200/'], verify_certs=True)
queries = []
#"In this example, the title and the question body of topic with id A.1 is printed."
topic_reader = TopicReader(topic_file_path)
dict_q_a = defaultdict(list)

# bert_better = ["A.21", "A.23", "A.29", "A.32", "A.38", "A.40", "A.5", "A.93", "A.98"]

topic_list = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        topic_list.append(line.split('\t')[0])

topic_list = list(set(topic_list))

list_p = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        list_p.append(line.split('\t')[2])

list_p = list(set(list_p))

# with open('psu-task1-mlt.base-auto-both-A.tsv', 'w') as eval_file:
count = 0 
for topic_id in tqdm(topic_list):
    if topic_id in better_bert:
        title = re.sub('<[^<]+?>', '', topic_reader.get_topic(topic_id).title)
        body = topic_reader.get_topic(topic_id).question
        body_pro = re.sub('<[^<]+?>', '', body)
        query = title + '. ' + body_pro
        queries.append(query)
        print(topic_id, query)
        print("============================")
        for i in query: 
            if i == '$': 
                count = count + 1
print(count/2/len(better_bert))
# Out:
# ...
# A.90 Question on the definition of an Inverse matrix. By definition, if $A$ is a $ n \times n $ matrix, an inverse of $A$ is an $ n \times n $ matrix $A^{-1}$ with the property that:  $$ A^{-1}A=\mathbb I_n \ \ \land \ \ AA^{-1}=\mathbb I_n \ \ \ \ (1)$$   where $ \mathbb I_n $ is the $ n \times n $ identity matrix.  Are there any cases where $ A^{-1}A=\mathbb I_n$ but $AA^{-1} \neq \mathbb I_n$ or the other way around (and thus making (1) a false statement) ?
# ...
# A.66 if $x,h \in \mathbb{R}^d$ and $A \in \mathbb{R}^{d\times d}$ is it possible to justify that $(x^TAh)^T = h^TA^Tx$?. if $x,h \in \mathbb{R}^d$ and $A \in \mathbb{R}^{d\times d}$  is it possible to justify that $(x^TAh)^T = h^TA^Tx$?
# ...

# %%
class Topic:
    """
    This class shows a topic for task 1. Each topic has an topic_id which is str, a title and question which
    is the question body and a list of tags.
    """

    def __init__(self, topic_id, title, question, tags):
        self.topic_id = topic_id
        self.title = title
        self.question = question
        self.lst_tags = tags


class TopicReader:
    """
    This class takes in the topic file path and read all the topics into a map. The key in this map is the topic id
    and the values are Topic which has 4 attributes: id, title, question and list of tags for each topic.

    To see each topic, use the get_topic method, which takes the topic id and return the topic in Topic object and
    you have access to the 4 attributes mentioned above.
    """

    def __init__(self, topic_file_path):
        self.__map_topics = self.__read_topics(topic_file_path)

    def __read_topics(self, topic_file_path):
        map_topics = {}
        tree = ET.parse(topic_file_path)
        root = tree.getroot()
        for child in root:
            topic_id = child.attrib['number']
            title = child[0].text
            question = child[1].text
            lst_tag = child[2].text.split(",")
            map_topics[topic_id] = Topic(topic_id, title, question, lst_tag)
        return map_topics

    def get_topic(self, topic_id):
        if topic_id in self.__map_topics:
            return self.__map_topics[topic_id]
        return None


es = Elasticsearch(['http://csxindex05:9200/'], verify_certs=True)
queries = []
#"In this example, the title and the question body of topic with id A.1 is printed."
topic_reader = TopicReader(topic_file_path)
dict_q_a = defaultdict(list)

# bert_better = ["A.21", "A.23", "A.29", "A.32", "A.38", "A.40", "A.5", "A.93", "A.98"]

topic_list = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        topic_list.append(line.split('\t')[0])

topic_list = list(set(topic_list))

list_p = []
with open('../runs/qrel_task1', 'r') as eval_file:
    for _,line in enumerate(eval_file):
        list_p.append(line.split('\t')[2])

list_p = list(set(list_p))

# with open('psu-task1-mlt.base-auto-both-A.tsv', 'w') as eval_file:
count = 0 

for topic_id in tqdm(topic_list):
    if topic_id in better_math:
        title = re.sub('<[^<]+?>', '', topic_reader.get_topic(topic_id).title)
        body = topic_reader.get_topic(topic_id).question
        body_pro = re.sub('<[^<]+?>', '', body)
        query = title + '. ' + body_pro
        queries.append(query)
#         print(topic_id, query)
#         print("============================")
        for i in query: 
            if i == '$': 
                count = count + 1
print(count/2/len(better_math))
# Out:
# ...
# 8.595238095238095

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'BM25+tf+tf.BERT', 'MathDowsers'
sizes = [8, 4]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Text')
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'BM25+tf+tf.BERT', 'MathDowsers'
sizes = [8, 23]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Formula')
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'BM25+tf+tf.BERT', 'MathDowsers'
sizes = [17, 14]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Text+Formula')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [16, 11]
plt.rcParams.update({'font.size': 27})

labels = ['Text', 'Formula', 'Text + Formula']
bert_count = [8, 8, 17]
math_count = [4, 23, 14]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, bert_count, width, label='BM25+tf+tf.BERT')
rects2 = ax.bar(x + width/2, math_count, width, label='MathDowsers')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of topics ids')
# ax.set_title('Scores by group and gender')
ax.set_xlabel('Dependence')

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

fig.savefig("count.pdf", bbox_inches='tight', dpi=600)

plt.show()

# %%
count_bert = 0
better_bert = []
better_math = []
for idx in dict_math:
    if dict_math[idx] < dict_bert[idx]:
        count_bert+=1
        print(idx,'bert', dict_bert[idx],dict_math[idx])
    else:
        print(idx,'mathdowserx', dict_bert[idx],dict_math[idx])
# Out:
# A.1 bert 0.5476 0.3756
# A.10 bert 0.5122 0.4605
# A.11 bert 0.1586 0.0
# A.12 mathdowserx 0.0503 0.2052
# A.13 mathdowserx 0.301 0.7542
# A.14 mathdowserx 0.0187 0.3192
# A.15 mathdowserx 0.0447 0.143
# A.16 mathdowserx 0.0571 0.2745
# A.17 bert 0.6512 0.4484
# A.18 bert 0.4446 0.3406
# A.19 mathdowserx 0.2386 0.3998
# A.20 mathdowserx 0.1746 0.2126
# A.21 bert 0.5449 0.0771
# A.23 bert 0.6535 0.1326
# A.24 bert 0.2943 0.1296
# A.26 mathdowserx 0.185 0.5564
# A.27 mathdowserx 0.2933 0.4501
# A.28 bert 0.2833 0.2271
# A.29 bert 0.5245 0.068
# A.3 mathdowserx 0.0221 0.2233
# A.30 mathdowserx 0.4147 0.6485
# A.32 bert 0.7617 0.3132
# A.33 bert 0.273 0.0696
# A.35 bert 0.4688 0.3598
# A.36 bert 0.3748 0.0361
# A.37 bert 0.2873 0.0247
# A.38 bert 0.6857 0.1255
# A.39 mathdowserx 0.1444 0.2063
# A.4 mathdowserx 0.2278 0.666
# A.40 bert 0.6347 0.1149
# A.41 bert 0.4791 0.2628
# A.42 bert 0.4834 0.3782
# A.43 mathdowserx 0.3183 0.6949
# A.44 bert 0.5104 0.0
# A.45 mathdowserx 0.4479 0.764
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [16, 11]
plt.rcParams.update({'font.size': 27})

labels = ['Text', 'Formula', 'Text + Formula']
bert_count = [0.482, 0.227, 0.333]
math_count = [0.272, 0.446, 0.272]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, bert_count, width, label='BM25+tf+tf.BERT')
rects2 = ax.bar(x + width/2, math_count, width, label='MathDowsers')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('NCDG\' score')
# ax.set_title('Scores by group and gender')
ax.set_xlabel('Dependence')

ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

fig.savefig("ndcg_dependence.pdf", bbox_inches='tight', dpi=600)

plt.show()
